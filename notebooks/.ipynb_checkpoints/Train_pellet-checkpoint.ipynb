# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Pellet-Position Model
# The pupose of this notebook is to clean DLC output data and create a model that predicts reaching attempts based on pellet position.

# %%
def read_in_file(data_path):
    return pd.read_csv(data_path)

data_path = '/Users/ib-nosirov/REU_2021/ReachingTaskDetector/tests/data/1 preopDLC_resnet_50_pre_post_opJul4shuffle1_550000.csv'
df = read_in_file(data_path)
df
# Out:
#          scorer DLC_resnet_50_pre_post_opJul4shuffle1_550000  \
# 0     bodyparts                                     left_paw
# 1        coords                                            x
# 2             0                            1418.123291015625
# 3             1                           1417.1771240234375
# 4             2                           1417.1341552734375
# ...         ...                                          ...
# 5802       5800                             1828.72607421875
# 5803       5801                           -2.679511070251465
# 5804       5802                           1827.8255615234375
# 5805       5803                           1827.8958740234375
# 5806       5804                           1827.7320556640625
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.1  \
# 0                                          left_paw
# 1                                                 y
# 2                                 663.1873168945312
# 3                                 665.2771606445312
# 4                                 673.0276489257812
# ...                                             ...
# 5802                             496.51812744140625
# 5803                              909.7489624023438
# 5804                              497.1662292480469
# 5805                                495.61669921875
# 5806                                495.54638671875
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.2  \
# 0                                          left_paw
# 1                                        likelihood
# 2                             0.0029328763484954834
# 3                             0.0017603039741516113
# 4                              0.001892387866973877
# ...                                             ...
# 5802                          0.0006741583347320557
# 5803                           0.001048952341079712
# 5804                          0.0012395083904266357
# 5805                          0.0014005601406097412
# 5806                          0.0016174614429473877
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.3  \
# 0                                         right_paw
# 1                                                 x
# 2                                 1415.287841796875
# 3                                    1421.103515625
# 4                                1421.4588623046875
# ...                                             ...
# 5802                              1842.999267578125
# 5803                             1843.0416259765625
# 5804                              1838.292724609375
# 5805                             1842.4547119140625
# 5806                             1842.4998779296875
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.4  \
# 0                                         right_paw
# 1                                                 y
# 2                                   666.13916015625
# 3                                  662.285400390625
# 4                                 665.6473388671875
# ...                                             ...
# 5802                              502.4154052734375
# 5803                             502.65606689453125
# 5804                             502.86212158203125
# 5805                                 500.0419921875
# 5806                              500.2495422363281
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.5  \
# 0                                         right_paw
# 1                                        likelihood
# 2                              0.003919333219528198
# 3                             0.0036325156688690186
# 4                              0.002454102039337158
# ...                                             ...
# 5802                          0.0006408393383026123
# 5803                          0.0006532073020935059
# 5804                          0.0005308985710144043
# 5805                          0.0007126033306121826
# 5806                          0.0007382035255432129
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.6  \
# 0                                             snout
# 1                                                 x
# 2                                  1827.03173828125
# 3                                   1825.4814453125
# 4                                1824.6593017578125
# ...                                             ...
# 5802                                    1837.921875
# 5803                             1837.8546142578125
# 5804                               1835.93896484375
# 5805                             1833.2249755859375
# 5806                             1833.1575927734375
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.7  \
# 0                                             snout
# 1                                                 y
# 2                                 516.9710693359375
# 3                                  521.850830078125
# 4                                 523.9973754882812
# ...                                             ...
# 5802                              510.5015563964844
# 5803                              511.0704040527344
# 5804                                 509.9638671875
# 5805                             505.99566650390625
# 5806                             506.35504150390625
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.8  \
# 0                                             snout
# 1                                        likelihood
# 2                                0.9622353315353394
# 3                                0.9883772730827332
# 4                                0.9757251739501953
# ...                                             ...
# 5802                             0.9997724294662476
# 5803                             0.9997918605804443
# 5804                             0.9997514486312866
# 5805                             0.9998542070388794
# 5806                             0.9998799562454224
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.9  \
# 0                                            pellet
# 1                                                 x
# 2                                  1418.34423828125
# 3                                 1417.277587890625
# 4                                1416.0828857421875
# ...                                             ...
# 5802                               1839.14306640625
# 5803                             1831.2552490234375
# 5804                              1830.409912109375
# 5805                               1840.70947265625
# 5806                             1829.8380126953125
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.10  \
# 0                                             pellet
# 1                                                  y
# 2                                    668.78564453125
# 3                                  672.2826538085938
# 4                                  676.6292114257812
# ...                                              ...
# 5802                               515.9965209960938
# 5803                               503.3423767089844
# 5804                               503.8017272949219
# 5805                               504.1811828613281
# 5806                              502.22540283203125
#
#      DLC_resnet_50_pre_post_opJul4shuffle1_550000.11
# 0                                             pellet
# 1                                         likelihood
# 2                                 0.9999691247940063
# 3                                 0.9999948740005493
# 4                                 0.9999954104423523
# ...                                              ...
# 5802                           0.0003822743892669678
# 5803                           0.0003370344638824463
# 5804                          0.00048047304153442383
# 5805                           0.0005065500736236572
# 5806                            0.000530630350112915
#
# [5807 rows x 13 columns]

# %%
[i for i in df.iloc[0, 1::3]]
# Out:
# ['left_paw', 'right_paw', 'snout', 'pellet']

# %%
df_pellet = df.iloc[2:, 10:13]
df_pellet = df_pellet.reset_index(drop=True)

# %%
df_pellet = df_pellet.rename(columns = {'DLC_resnet_50_pre_post_opJul4shuffle1_550000.9': 'x_coord', 'DLC_resnet_50_pre_post_opJul4shuffle1_550000.10': 'y_coord', 'DLC_resnet_50_pre_post_opJul4shuffle1_550000.11': 'prob'})

# %%
df_pellet = df_pellet.to_numpy(dtype ='float32')

# %%
df_pellet.shape
# Out:
# (5805, 3)

# %%
for i in range(df_pellet.shape[0]):
    if (df_pellet[i, 2] < 0.5):
        df_pellet[i, 1] = 0
        df_pellet[i, 0] = 0

# %%
import numpy as np 
from matplotlib import pyplot as plt 

t = np.arange(5805)
y = df_pellet[:,1]
prob = df_pellet[:,2]
plt.title("y-position vs time") 
plt.xlabel("time") 
plt.ylabel("y-position") 
plt.scatter(t,y, c=prob)
plt.show()

# %%
t = np.arange(5805)
x = df_pellet[:,0]
prob = df_pellet[:,2]
plt.title("x-position vs time") 
plt.xlabel("time") 
plt.ylabel("x-position") 
plt.scatter(t, x, c=prob)
plt.show()

# %%
def convert_to_time(time):
    seconds = int(time % 60)
    minutes = int(time / 60)
    return (minutes, seconds)

# %%
# convert to time stamps
def output_time_stamps(data_frame):
    attempt_ongoing = False
    for i in range(data_frame.shape[0]):
        if (data_frame[i, 2] > 0.5):
            if (not attempt_ongoing):
                attempt_ongoing = True
                time = convert_to_time(i / 29)
                print("Start Attempt: ", str(time[0]) + ":" + str(time[1]))
        else:
            if (attempt_ongoing):
                time = convert_to_time(i / 29)
                print("End Attempt: ", str(time[0]) + ":" + str(time[1]))
                attempt_ongoing = False

# %%
output_time_stamps(df_pellet)
# Out:
# Start Attempt:  0:0
# End Attempt:  0:7
# Start Attempt:  0:8
# End Attempt:  0:9
# Start Attempt:  0:10
# End Attempt:  0:10
# Start Attempt:  0:12
# End Attempt:  0:14
# Start Attempt:  0:23
# End Attempt:  0:37
# Start Attempt:  0:47
# End Attempt:  0:52
# Start Attempt:  0:52
# End Attempt:  1:4
# Start Attempt:  1:11
# End Attempt:  1:21
# Start Attempt:  1:26
# End Attempt:  1:28
# Start Attempt:  1:42
# End Attempt:  1:44
# Start Attempt:  1:44
# End Attempt:  1:45
# Start Attempt:  1:45
# End Attempt:  1:45
# Start Attempt:  1:45
# End Attempt:  1:45
# Start Attempt:  1:45
# End Attempt:  1:46
# Start Attempt:  1:46
# End Attempt:  1:46
# Start Attempt:  1:46
# End Attempt:  1:46
# Start Attempt:  1:47
# End Attempt:  1:47
# Start Attempt:  1:48
# End Attempt:  1:48
# Start Attempt:  1:51
# End Attempt:  1:51
# Start Attempt:  1:53
# End Attempt:  1:55
# Start Attempt:  1:59
# End Attempt:  1:59
# Start Attempt:  2:1
# End Attempt:  2:1
# Start Attempt:  2:1
# End Attempt:  2:1
# Start Attempt:  2:1
# End Attempt:  2:3
# Start Attempt:  2:11
# End Attempt:  2:13
# Start Attempt:  2:16
# End Attempt:  2:16
# Start Attempt:  2:19
# End Attempt:  2:19
# Start Attempt:  2:23
# End Attempt:  2:23
# Start Attempt:  2:23
# End Attempt:  2:23
# Start Attempt:  2:28
# End Attempt:  2:29
# Start Attempt:  2:29
# End Attempt:  2:34
# Start Attempt:  2:34
# End Attempt:  2:34
# Start Attempt:  2:36
# End Attempt:  2:36
# Start Attempt:  2:36
# End Attempt:  2:38
# Start Attempt:  2:45
# End Attempt:  2:45
# Start Attempt:  2:45
# End Attempt:  2:45
# Start Attempt:  2:47
# End Attempt:  2:48
# Start Attempt:  2:58
# End Attempt:  2:59
# Start Attempt:  3:6
# End Attempt:  3:6
# Start Attempt:  3:6
# End Attempt:  3:7
# Start Attempt:  3:7
# End Attempt:  3:7
# Start Attempt:  3:7
# End Attempt:  3:8
# Start Attempt:  3:8
# End Attempt:  3:8
# Start Attempt:  3:8
# End Attempt:  3:11
# Start Attempt:  3:13
# End Attempt:  3:15

# %%
# %jt -l
# Out:
# UsageError: Line magic function `%jt` not found.
