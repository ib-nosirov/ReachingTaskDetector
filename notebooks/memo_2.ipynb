# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# show jupyter notebook where to look
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import reachingtaskdetector.load_data as ld

# %% [markdown]
# # Memo 2: Position-based modelling

# %% [markdown]
# The purpose of this notebook is to model the new round of data based on particle positions.

# %%
data_path = '../tests/data/IMG_42860.csv'
np_data = ld.create_np_arr(data_path)
np_pellet_arrs = np_data['pellet']

# %%
import reachingtaskdetector.plot_data as plot
np_pellet_copy = np_pellet_arrs
for i in range(np_pellet_copy.shape[0]):
    if (np_pellet_copy[i, 2] < 0.8):
        np_pellet_copy[i,0] = 0
plot.make_scatterplot(np.arange(np_pellet_copy.shape[0]), np_pellet_copy[:,0],
                            'x-position vs time', 'time', 'x-position', np_pellet_copy[:,2])

# %%
import reachingtaskdetector.model_position as m_position
timestamps_list = m_position.create_timestamps(np_pellet_arrs)
m_position.output_timestamps(timestamps_list)
# Out:
# Start Attempt:  0.05367231638418079:3.2203389830508473
# End Attempt:  0.053954802259887004:3.23728813559322
# Start Attempt:  0.054237288135593226:3.2542372881355934
# End Attempt:  0.05451977401129944:3.2711864406779663
# Start Attempt:  0.05480225988700565:3.288135593220339
# End Attempt:  0.05508474576271186:3.305084745762712
# Start Attempt:  0.05536723163841808:3.3220338983050848
# End Attempt:  0.05564971751412429:3.3389830508474576
# Start Attempt:  0.05593220338983051:3.3559322033898304
# End Attempt:  0.05621468926553672:3.3728813559322033
# Start Attempt:  0.05649717514124294:3.389830508474576
# End Attempt:  0.05677966101694915:3.406779661016949
# Start Attempt:  0.05734463276836158:3.440677966101695
# End Attempt:  0.06271186440677966:3.76271186440678
# Start Attempt:  0.06299435028248587:3.7796610169491527
# End Attempt:  0.06327683615819209:3.7966101694915255
# Start Attempt:  0.0635593220338983:3.8135593220338984
# End Attempt:  0.06384180790960452:3.830508474576271
# ...

# %%
np_pellet_arrs[:,2]
# Out:
# array([0.01746222, 0.01507065, 0.00909802, ..., 0.16271189, 0.1758213 ,
#        0.18654719], dtype=float32)
